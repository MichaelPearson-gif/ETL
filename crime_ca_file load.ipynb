# %%
import pandas as pd
from sqlalchemy import create_engine
from config_mg import passwd

# %%
csv_file = "./Crime_ca.csv"
crime_data_df = pd.read_csv(csv_file,encoding = "ISO-8859-1")
crime_data_df.head()
# Out:
# C:\Users\mghan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   ind_id                                 ind_definition  reportyear  \
# 0    752  Number of Violent Crimes per 1,000 Population      2000.0
# 1    752  Number of Violent Crimes per 1,000 Population      2000.0
# 2    752  Number of Violent Crimes per 1,000 Population      2000.0
# 3    752  Number of Violent Crimes per 1,000 Population      2000.0
# 4    752  Number of Violent Crimes per 1,000 Population      2000.0
#
#    race_eth_code race_eth_name geotype  geotypevalue     geoname  county_fips  \
# 0            9.0         Total      CA           6.0  California          NaN
# 1            9.0         Total      CA           6.0  California          NaN
# 2            9.0         Total      CA           6.0  California          NaN
# ...

# %%
crime_data_df.columns
# Out:
# Index(['ind_id', 'ind_definition', 'reportyear', 'race_eth_code',
#        'race_eth_name', 'geotype', 'geotypevalue', 'geoname', 'county_fips',
#        'county_name', 'region_code', 'region_name', 'strata_name_code',
#        'strata_name', 'strata_level_name_code', 'strata_level_name',
#        'numerator', 'denominator', 'rate', 'll_95ci', 'ul_95ci', 'se', 'rse',
#        'ca_decile', 'ca_rr', 'dof_population', 'version'],
#       dtype='object')

# %%
clean_crime_data = crime_data_df[['reportyear','geotype','geoname','county_name','region_name','strata_level_name','numerator', 'denominator', 'rate']]
CA_crime_data = clean_crime_data[clean_crime_data['geotype']=='CA']
CA_crime_data
# Out:
#        reportyear geotype     geoname county_name region_name  \
# 0          2000.0      CA  California         NaN         NaN
# 1          2000.0      CA  California         NaN         NaN
# 2          2000.0      CA  California         NaN         NaN
# 3          2000.0      CA  California         NaN         NaN
# 4          2000.0      CA  California         NaN         NaN
# 3391       2001.0      CA  California         NaN         NaN
# 3392       2001.0      CA  California         NaN         NaN
# 3393       2001.0      CA  California         NaN         NaN
# 3394       2001.0      CA  California         NaN         NaN
# 3395       2001.0      CA  California         NaN         NaN
# 6782       2002.0      CA  California         NaN         NaN
# 6783       2002.0      CA  California         NaN         NaN
# 6784       2002.0      CA  California         NaN         NaN
# 6785       2002.0      CA  California         NaN         NaN
# ...

# %%
CA_crime_data = CA_crime_data.rename(columns={"numerator": "no_of_crime", "denominator":"population"})
CA_crime_data['rate'] = (CA_crime_data['no_of_crime']/CA_crime_data['population'])*1000
CA_crime_data.reset_index()   
CA_crime_data.index.name = 'id'
CA_crime_data
# Out:
#        reportyear geotype     geoname county_name region_name  \
# id
# 0          2000.0      CA  California         NaN         NaN
# 1          2000.0      CA  California         NaN         NaN
# 2          2000.0      CA  California         NaN         NaN
# 3          2000.0      CA  California         NaN         NaN
# 4          2000.0      CA  California         NaN         NaN
# 3391       2001.0      CA  California         NaN         NaN
# 3392       2001.0      CA  California         NaN         NaN
# 3393       2001.0      CA  California         NaN         NaN
# 3394       2001.0      CA  California         NaN         NaN
# 3395       2001.0      CA  California         NaN         NaN
# 6782       2002.0      CA  California         NaN         NaN
# 6783       2002.0      CA  California         NaN         NaN
# 6784       2002.0      CA  California         NaN         NaN
# 6785       2002.0      CA  California         NaN         NaN
# ...

# %%
CA_crime_data.columns
#CA_crime_data.index.dtype
# Out:
# Index(['reportyear', 'geotype', 'geoname', 'county_name', 'region_name',
#        'strata_level_name', 'no_of_crime', 'population', 'rate'],
#       dtype='object')

# %%
#Create database connection

db_url = ('postgres://postgres:{password}@localhost:5432/ca_crime_db').format(password = passwd)
engine = create_engine(db_url)
   
connection = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['crime']

# %%
CA_crime_data.to_sql(name='crime', con=engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from crime', con=engine).head()
# Out:
#    id  reportyear geotype     geoname county_name region_name  \
# 0   0        2000      CA  California        None        None
# 1   1        2000      CA  California        None        None
# 2   2        2000      CA  California        None        None
# 3   3        2000      CA  California        None        None
# 4   4        2000      CA  California        None        None
#
#                        strata_level_name  no_of_crime  population  rate
# 0                     Aggravated assault       138325    33847694     4
# 1                          Forcible rape         9784    33847694     0
# 2  Murder and non-negligent manslaughter         2079    33847694     0
# 3                                Robbery        60237    33847694     2
# 4                    Violent crime total       210448    33847694     6
