# %%
# Dependencies
import pandas as pd
from datetime import date
from datetime import datetime
from pygeocoder import Geocoder
import json
import requests
from config import api_key
from pprint import pprint

# %%
# Import the data
file = "./Resources/database.csv"
earthquake_df = pd.read_csv(file)
earthquake_df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
# Get a list of all the columns
earthquake_df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %% [markdown]
# # Transforming the Data

# %%
# Make a list of columns that will be dropped
delete_columns = ['Type', 'Time', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude Type', \
                  'Magnitude Error','Magnitude Seismic Stations','Azimuthal Gap', 'Horizontal Distance', \
                  'Horizontal Error', 'Root Mean Square', 'Source', 'Location Source', 'Magnitude Source', 'Status']
# Drop the unwanted columns
df = earthquake_df.drop(delete_columns, axis=1)

df.tail()
# Out:
#              Date  Latitude  Longitude  Magnitude          ID
# 23407  12/28/2016   38.3917  -118.8941        5.6  NN00570710
# 23408  12/28/2016   38.3777  -118.8957        5.5  NN00570744
# 23409  12/28/2016   36.9179   140.4262        5.9  US10007NAF
# 23410  12/29/2016   -9.0283   118.6639        6.3  US10007NL0
# 23411  12/30/2016   37.3973   141.4103        5.5  US10007NTD

# %%
df.count()
# Out:
# Date         23412
# Latitude     23412
# Longitude    23412
# Magnitude    23412
# ID           23412
# dtype: int64

# %%
# Filter to only show California
# Lowest point in CA is latitude and longitude 32.633523, -117.076889
# Highest point in CA is latitude and longitude 41.975083, -122.541203
states = []
for i in range(0, len(df['Latitude'])):
    coord = f"{df['Latitude'][i]}, {df['Longitude'][i]}"
    params = {
        "latlng": coord,
        "key": api_key,
        'reult_type': "administrative_area_level_1"
    }

    url = f"https://maps.googleapis.com/maps/api/geocode/json"
    response = requests.get(url, params).json()
#     state_name = response['results'][0]['address_components'][5]['long_name']
#     states.append(state_name)
    
print(response['results'][0]['address_components'][5]['long_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c23b337f8080> in <module>
#      12
#      13     url = f"https://maps.googleapis.com/maps/api/geocode/json"
# ---> 14     response = requests.get(url, params).json()
#      15 #     state_name = response['results'][0]['address_components'][5]['long_name']
#      16 #     states.append(state_name)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...
